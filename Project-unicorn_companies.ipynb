# %% [markdown]
# ### Problem Statement:- This project understand  factors contribute most to a company's valuation. Analyze the dataset to identify key drivers of valuation growth, such as industry, funding amounts, returns,investors or joining year to unicorn.
#
# #### Objectives:
# 1. which unicorn company has the highest/lowest return on investments?
# 2. which companies get highest/lowest funding?
# 3. which continent/country /city has most unicorn companies?
# 4. In which year most of the unicorn companies are founded?
# 5. In which industry most unicorn companies founded?
# 6. In which of the continent which industry is developed?
# 7. which country is developed in which industry?
# 8. which investors are funding more/less wrt industry?
# 9. How many companies take less/more years to become unicorn?

# %% [markdown]
# ### Import Library

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame,Series
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
comp=pd.read_csv("Unicorn_Companies.csv")
comp
# Out:
#                 Company Date Joined                             Industry  \
# 0            1047 Games   9/14/2021         Internet software & services
# 1                 1KMXC   8/30/2021                             Hardware
# 2             1Password    7/8/2021                        Cybersecurity
# 3             4Paradigm  12/19/2018              Artificial Intelligence
# 4             56PINGTAI   1/25/2021  Supply chain, logistics, & delivery
# ...                 ...         ...                                  ...
# 1069  ZongMu Technology    6/3/2021                Auto & transportation
# 1070               Zopa  10/19/2021                              Fintech
# 1071               Zume   11/1/2018                    Consumer & retail
# 1072          Zuoyebang   7/18/2018                               Edtech
# 1073              Zwift   9/16/2020      E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded  \
# ...

# %%
comp.shape   #size of the dataset
# Out:
# (1074, 12)

# %% [markdown]
# ### EDA & Visualization

# %%
comp.head(10)    # first 10 rows
# Out:
#              Company Date Joined                             Industry  \
# 0         1047 Games   9/14/2021         Internet software & services
# 1              1KMXC   8/30/2021                             Hardware
# 2          1Password    7/8/2021                        Cybersecurity
# 3          4Paradigm  12/19/2018              Artificial Intelligence
# 4          56PINGTAI   1/25/2021  Supply chain, logistics, & delivery
# 5          58 Daojia  10/12/2015         Internet software & services
# 6             6Sense   3/30/2021              Artificial Intelligence
# 7          A24 Films    3/9/2022                                Other
# 8  ABL Space Systems   3/25/2021                                Other
# 9             Abogen  11/29/2021                               Health
#
#             City        Country      Continent  Year Founded  \
# 0    Zephyr Cove  United States  North America          2017
# 1       Hangzhou          China           Asia          2014
# ...

# %%
comp.tail(10)  #last 10 rows
# Out:
#                 Company Date Joined                             Industry  \
# 1064           Zihaiguo    5/6/2021                    Consumer & retail
# 1065              Zilch  11/10/2021                              Fintech
# 1066            Zipline   5/20/2019  Supply chain, logistics, & delivery
# 1067             Ziroom   1/17/2018      E-commerce & direct-to-consumer
# 1068             ZocDoc   8/20/2015                               Health
# 1069  ZongMu Technology    6/3/2021                Auto & transportation
# 1070               Zopa  10/19/2021                              Fintech
# 1071               Zume   11/1/2018                    Consumer & retail
# 1072          Zuoyebang   7/18/2018                               Edtech
# 1073              Zwift   9/16/2020      E-commerce & direct-to-consumer
#
#                      City         Country      Continent  Year Founded  \
# 1064            Chongqing           China           Asia          2018
# ...

# %%
comp.nunique()    #unique values
# Out:
# Company             1073
# Date Joined          639
# Industry              15
# City                 259
# Country               46
# Continent              6
# Year Founded          35
# Select Investors    1058
#  Funds               538
# Valuation             30
# Year Joined           13
# Return               763
# dtype: int64

# %% [markdown]
# ### Inference:
# 1.There are 1073 companies are founded in 259 cities of 46 countries which are situated in 6 continents.

# %%
comp.isnull().sum()     #null values
# Out:
# Company             0
# Date Joined         0
# Industry            0
# City                0
# Country             0
# Continent           0
# Year Founded        0
# Select Investors    0
#  Funds              0
# Valuation           0
# Year Joined         0
# Return              0
# dtype: int64

# %%
comp.info()  # information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Date Joined       1074 non-null   object
#  2   Industry          1074 non-null   object
#  3   City              1074 non-null   object
#  4   Country           1074 non-null   object
#  5   Continent         1074 non-null   object
#  6   Year Founded      1074 non-null   int64
#  7   Select Investors  1074 non-null   object
#  8    Funds            1074 non-null   int64
#  9   Valuation         1074 non-null   int64
#  10  Year Joined       1074 non-null   int64
#  11  Return            1074 non-null   int64
# dtypes: int64(5), object(7)
# memory usage: 100.8+ KB

# %%
comp.describe()  #Description
# Out:
#        Year Founded         Funds      Valuation  Year Joined         Return
# count   1074.000000   1074.000000    1074.000000  1074.000000    1074.000000
# mean    2012.891993    671.148045    3455.307263  2019.900372    2784.159218
# std        5.694577   3004.989338    8547.022216     1.999613    8625.055052
# min     1919.000000      0.000000    1000.000000  2007.000000  -89470.000000
# 25%     2011.000000    225.250000    1000.000000  2019.000000     765.000000
# 50%     2014.000000    376.000000    2000.000000  2021.000000    1503.000000
# 75%     2016.000000    613.500000    3000.000000  2021.000000    2601.750000
# max     2021.000000  90470.000000  180000.000000  2022.000000  172000.000000

# %% [markdown]
# #### Inference:
#
# 1. The highest funding for company from investor is 90.47 B$.
#
# 2. The highest valuation from a company is 180 B$.
#
# 3. The first company is founded in 1919.

# %% [markdown]
# ##### In which industry most unicorn companies founded?

# %%
comp.columns
# Out:
# Index(['Company', 'Date Joined', 'Industry', 'City', 'Country', 'Continent',
#        'Year Founded', 'Select Investors', ' Funds', 'Valuation',
#        'Year Joined', 'Return'],
#       dtype='object')

# %%
comp[' Funds']
# Out:
# 0        127
# 1         86
# 2        920
# 3       1000
# 4        188
#         ...
# 1069     376
# 1070     792
# 1071     423
# 1072    3000
# 1073     620
# Name:  Funds, Length: 1074, dtype: int64

# %%
sns.distplot(comp[' Funds'])
plt.show()

# %%
comp["Industry"].value_counts()
# Out:
# Fintech                                224
# Internet software & services           205
# E-commerce & direct-to-consumer        111
# Artificial Intelligence                 84
# Health                                  74
# Other                                   58
# Supply chain, logistics, & delivery     57
# Cybersecurity                           50
# Data management & analytics             41
# Mobile & telecommunications             38
# Hardware                                34
# Auto & transportation                   31
# Edtech                                  28
# Consumer & retail                       25
# Travel                                  14
# Name: Industry, dtype: int64

# %%
sns.barplot(x=comp["Industry"].value_counts(),y=comp["Industry"].value_counts().index)
plt.show()

# %% [markdown]
# #### Inference:
# 1. 'Fintech' is the highest unicorn generating industry whether 'Travel' is the lowest unicorn generating industry.

# %% [markdown]
# ##### which continent and country and city has most unicorn companies?

# %%
comp["City"].value_counts().head(10)
# Out:
# San Francisco    152
# New York         103
# Beijing           63
# Shanghai          44
# London            34
# Bengaluru         29
# Paris             19
# Shenzhen          19
# Palo Alto         18
# Berlin            17
# Name: City, dtype: int64

# %%
plt.figure(figsize=(15,15))
sns.countplot(x="City", order = comp["City"].value_counts().head(10).index,data=comp)
plt.grid(axis="y",color="r", linestyle="--")
plt.xticks(rotation=90)
plt.show()

# %%
comp["Continent"].value_counts()
# Out:
# North America    589
# Asia             310
# Europe           143
# South America     21
# Oceania            8
# Africa             3
# Name: Continent, dtype: int64

# %%
sns.countplot(order=comp["Continent"].value_counts().index,x="Continent",data=comp)
plt.show()

# %%
comp["Country"].value_counts().head(10)
# Out:
# United States     562
# China             173
# India              65
# United Kingdom     43
# Germany            26
# France             24
# Israel             20
# Canada             19
# Brazil             16
# South Korea        12
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(x="Country", order = comp["Country"].value_counts().head(10).index,data=comp)
plt.show()

# %% [markdown]
# ##### Inference:
# This above graph shows top 11 countries who generate more unicorn companies.
# In the year 2021 most of companies of top 11 countries gained unicorn status the top one is US after that China and India.
#
# The North America,Asia and Europe are the top 3 continents who generate more unicorns.

# %% [markdown]
# ##### In which year most of the unicorn companies are founded?

# %%
comp["Year Founded"].value_counts().head(25)
# Out:
# 2015    155
# 2016    110
# 2014    109
# 2012     95
# 2013     87
# 2011     82
# 2017     75
# 2018     61
# 2019     45
# 2010     40
# 2009     34
# 2008     27
# 2020     25
# 2007     24
# 2006     15
# 2005     14
# 2000     11
# 2021     10
# 2001      9
# 2003      8
# 1999      8
# 2004      8
# 1998      5
# 2002      4
# 1995      2
# Name: Year Founded, dtype: int64

# %% [markdown]
# ### Inference:
# 1. The top 5 industries in which companies become unicorn are Fintech,Internet software & services,E-commerce & direct-to-consumer,Artificial Intelligence and Health.
# 2. The top 3 countries and cities where most of the companies are founded are:
#
#     continents: North America,Asia and Europe
#
#    countries: US,China,India,UK
#
#    cities: San Francisco,New York,Beijing,Shanghai
#
#
# 3. The most of the companies are founded in the year 2015.

# %%
comp["years_to_unicorn"] = comp["Year Joined"] - comp["Year Founded"]

# %%
comp
# Out:
#                 Company Date Joined                             Industry  \
# 0            1047 Games   9/14/2021         Internet software & services
# 1                 1KMXC   8/30/2021                             Hardware
# 2             1Password    7/8/2021                        Cybersecurity
# 3             4Paradigm  12/19/2018              Artificial Intelligence
# 4             56PINGTAI   1/25/2021  Supply chain, logistics, & delivery
# ...                 ...         ...                                  ...
# 1069  ZongMu Technology    6/3/2021                Auto & transportation
# 1070               Zopa  10/19/2021                              Fintech
# 1071               Zume   11/1/2018                    Consumer & retail
# 1072          Zuoyebang   7/18/2018                               Edtech
# 1073              Zwift   9/16/2020      E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded  \
# ...

# %%
comp["Year Joined"].value_counts()
# Out:
# 2021    521
# 2022    116
# 2020    108
# 2019    104
# 2018    103
# 2017     43
# 2015     35
# 2016     21
# 2014     13
# 2012      4
# 2013      3
# 2011      2
# 2007      1
# Name: Year Joined, dtype: int64

# %%
print(comp[(comp["years_to_unicorn"] == comp["years_to_unicorn"].max())].value_counts())
comp[(comp["years_to_unicorn"] == comp["years_to_unicorn"].min())].value_counts()
# Out:
# Company               Date Joined  Industry  City        Country  Continent  Year Founded  Select Investors   Funds  Valuation  Year Joined  Return  years_to_unicorn
# Otto Bock HealthCare  6/24/2017    Health    Duderstadt  Germany  Europe     1919          EQT Partners      0       4000       2017         4000    98                  1
# dtype: int64
# Company                Date Joined  Industry                         City            Country        Continent      Year Founded  Select Investors                                                         Funds  Valuation  Year Joined  Return  years_to_unicorn
# Avant                  12/17/2012   Artificial Intelligence          Chicago         United States  North America  2012          RRE Ventures, Tiger Global, August Capital                              658     2000       2012         1342    0                   1
# ...

# %%
comp.groupby(['Company','Industry','Date Joined'])['years_to_unicorn'].min().sort_values(ascending=True).head(10)
# Out:
# Company                Industry                         Date Joined
# candy.com              Fintech                          10/21/2021     0
# Ola Electric Mobility  Auto & transportation            7/2/2019       0
# Avant                  Artificial Intelligence          12/17/2012     0
# Playco                 Other                            9/21/2020      0
# Mensa Brands           Other                            11/16/2021     0
# Jokr                   E-commerce & direct-to-consumer  12/2/2021      0
# ClickHouse             Data management & analytics      10/28/2021     0
# Flink Food             E-commerce & direct-to-consumer  12/1/2021      0
# GlobalBees             E-commerce & direct-to-consumer  12/28/2021     0
# Yuga Labs              Fintech                          3/22/2022      1
# Name: years_to_unicorn, dtype: int64

# %%
sns.regplot(x='Valuation',y='Return',data=comp,color='brown')
plt.title('valuation vs return ')
plt.show()

# %% [markdown]
# #### Inference:
# 1. The most of the companies are founded in 2015,but most of the companies become unicorn at 2021.
# 2. The most of companies take 6 yrs to gain unicorn status.
# 3. The company takes the more years to gain unicorn status is 98 years.
# 4. The company is already an unicorn ie. means there founded and joined year is same.

# %% [markdown]
# ##### which unicorn company has the highest/lowest return on investments?

# %%
comp["Return"].describe()
# Out:
# count      1074.000000
# mean       2737.604283
# std        8765.785802
# min      -89470.000000
# 25%         764.250000
# 50%        1503.000000
# 75%        2601.750000
# max      172000.000000
# Name: Return, dtype: float64

# %% [markdown]
# #### Inference:
# 1. The highest returns on investment is 172 B$.
#
# 2. The lowest returns on investment  is -89.4 B$.

# %% [markdown]
# ##### In which of the continent which industry is developed?

# %%
comp.groupby(['Continent'])['Industry'].value_counts()
# Out:
# Continent      Industry
# Africa         Fintech                                  2
#                Mobile & telecommunications              1
# Asia           E-commerce & direct-to-consumer         54
#                Fintech                                 38
#                Internet software & services            31
#                Artificial Intelligence                 26
#                Supply chain, logistics, & delivery     26
#                Auto & transportation                   20
#                Edtech                                  19
#                Mobile & telecommunications             19
#                Hardware                                18
#                Health                                  15
#                Other                                   14
#                Consumer & retail                       12
#                Cybersecurity                            7
#                Travel                                   7
# ...

# %% [markdown]
# #### Inference:
# 1. Africa continent has only 2 industry developed ie. Fintech,Mobile & telecommunications.
# 2. In Asia, the industry which is more developed and unicorn generating is E-commerce & direct-to-consumer after that fintech and many more but the bottom one is travel industry.
# 3. In North America ,Internet software & services,Fintech are more developed than others whether travel is bottom one industry.
# 4. In Europe,  Fintech is more developed and Cybersecurity,Edtech is less developed.
# 5. In Oceania, the three industries aredeveloped: Internet software & services,Fintech and E-commerce & direct-to-consumer.
# 6. In South America, Fintech is more developed whether Mobile & telecommunications is less developed.

# %% [markdown]
# #####  which industry  is developed in which country?

# %%
comp.groupby(['Country'])['Industry'].value_counts()
# Out:
# Country        Industry
# Argentina      Fintech                            1
# Australia      Internet software & services       5
#                Fintech                            2
#                E-commerce & direct-to-consumer    1
# Austria        Edtech                             1
#                                                  ..
# United States  Edtech                             7
#                Auto & transportation              4
#                Travel                             1
# Vietnam        Fintech                            1
#                Internet software & services       1
# Name: Industry, Length: 194, dtype: int64

# %%
comp.groupby(['Country'])['Industry'].max()
# Out:
# Country
# Argentina                                           Fintech
# Australia                      Internet software & services
# Austria                                             Fintech
# Bahamas                                             Fintech
# Belgium                        Internet software & services
# Bermuda                             Artificial Intelligence
# Brazil                  Supply chain, logistics, & delivery
# Canada                                               Travel
# Chile                               Artificial Intelligence
# China                                                Travel
# Colombia                Supply chain, logistics, & delivery
# Croatia                         Mobile & telecommunications
# Czech Republic          Supply chain, logistics, & delivery
# Denmark                                             Fintech
# Estonia                               Auto & transportation
# ...

# %% [markdown]
# #### Inference:
# The above shows the industries which are most developed as per country.

# %%
sns.barplot(x="Industry",y="years_to_unicorn",data=comp)
plt.title("Bar plot of maximum years taken by company to become unicorn per industry")
plt.xlabel("Industry")
plt.ylabel("Maximum number of years")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### Unicorn startups in India

# %%
india=comp[comp["Country"]=="India"]
india
# Out:
#            Company Date Joined                             Industry  \
# 15          BYJU's   7/25/2017                               Edtech
# 41          Swiggy   6/21/2018  Supply chain, logistics, & delivery
# 48       OYO Rooms   9/25/2018                               Travel
# 71         Dream11    4/9/2019         Internet software & services
# 74        Razorpay  10/11/2020                              Fintech
# ...            ...         ...                                  ...
# 955        Licious   10/5/2021      E-commerce & direct-to-consumer
# 967   Mensa Brands  11/16/2021                                Other
# 981       NoBroker  11/23/2021         Internet software & services
# 1026         Slice  11/28/2021                              Fintech
# 1052       Vedantu   9/29/2021                               Edtech
#
#            City Country Continent  Year Founded  \
# 15    Bengaluru   India      Asia          2008
# 41    Bengaluru   India      Asia          2014
# ...

# %% [markdown]
# #####  Valuations of startup unicorn companies in India

# %%
plt.figure(figsize=(15,6))
sns.lineplot(india,x="Company",y="Valuation")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### Which industry takes less years to become unicorn?

# %%
comp.groupby(['Industry'])['years_to_unicorn'].min()
# Out:
# Industry
# Artificial Intelligence                0
# Auto & transportation                  0
# Consumer & retail                      1
# Cybersecurity                          1
# Data management & analytics            0
# E-commerce & direct-to-consumer        0
# Edtech                                 3
# Fintech                                0
# Hardware                               1
# Health                                 1
# Internet software & services           1
# Mobile & telecommunications            1
# Other                                  0
# Supply chain, logistics, & delivery    2
# Travel                                 3
# Name: years_to_unicorn, dtype: int64

# %%
comp.groupby(['Industry'])['years_to_unicorn'].max()
# Out:
# Industry
# Artificial Intelligence                15
# Auto & transportation                  14
# Consumer & retail                      37
# Cybersecurity                          21
# Data management & analytics            22
# E-commerce & direct-to-consumer        24
# Edtech                                 17
# Fintech                                27
# Hardware                               18
# Health                                 98
# Internet software & services           21
# Mobile & telecommunications            20
# Other                                  37
# Supply chain, logistics, & delivery    20
# Travel                                 14
# Name: years_to_unicorn, dtype: int64

# %% [markdown]
# ##### Inferene:
# 1. Artificial Intelligence, Auto & transportation,Data management & analytics,E-commerce & direct-to-consumer,Fintech and Other are the industries which took less years to become unicorn.

# %% [markdown]
# ##### Unicorn startups in Bengaluru city

# %%
ben=comp[comp["City"]=="Bengaluru"]
ben
# Out:
#                      Company Date Joined                             Industry  \
# 15                    BYJU's   7/25/2017                               Edtech
# 41                    Swiggy   6/21/2018  Supply chain, logistics, & delivery
# 74                  Razorpay  10/11/2020                              Fintech
# 87                      CRED    4/6/2021                              Fintech
# 89                  Ola Cabs  10/27/2014                Auto & transportation
# 128                DailyHunt  12/22/2020         Internet software & services
# 130                   Meesho    4/5/2021         Internet software & services
# 161    Ola Electric Mobility    7/2/2019                Auto & transportation
# 201                ShareChat    4/8/2021         Internet software & services
# 260          Digit Insurance   1/15/2021                              Fintech
# 274                Unacademy    9/2/2020                               Edtech
# ...

# %% [markdown]
# ##### which unicorn company has the highest or lowest return on investments?

# %%
comp.groupby(['Company'])['Return'].max().sort_values(ascending=False)
# Out:
# Company
# Bytedance          172000
# SHEIN               98000
# SpaceX              93000
# Stripe              93000
# Klarna              42000
#                     ...
# Magic Leap          -1000
# Fair                -1000
# ECARX              -29940
# Kajabi             -48500
# Miaoshou Doctor    -89470
# Name: Return, Length: 1073, dtype: int64

# %% [markdown]
# ##### Inference:
# 1. The top 3 companies which have highest returns are :
#
#    i) Bytedance (172 B$)
#
#   ii) SHEIN (98 B$)
#
#  iii) SpaceX  (93 B$)
#
#  iv)  Stripe (93 B$)
#
# 2. The top 3 companies which have lowest returns are : Miaoshou Doctor,Kajabi and ECARX .

# %% [markdown]
# ##### How many companies take less or more years to become unicorn?

# %%
comp.groupby(["Company","Year Founded"])["years_to_unicorn"].mean()
# Out:
# Company       Year Founded
# 1047 Games    2017             4.0
# 1KMXC         2014             7.0
# 1Password     2005            16.0
# 4Paradigm     2015             3.0
# 56PINGTAI     2013             8.0
#                               ...
# impact.com    2008            13.0
# o9 Solutions  2009            11.0
# reddit        2005            12.0
# solarisBank   2016             5.0
# wefox         2014             5.0
# Name: years_to_unicorn, Length: 1074, dtype: float64

# %%
top_10 = pd.DataFrame(comp.groupby(['Country'])['Valuation'].sum().sort_values(ascending=False)[:10])
top_10
# Out:
#                 Valuation
# Country
# United States     1933000
# China              696000
# India              196000
# United Kingdom     195000
# Germany             72000
# Sweden              63000
# Australia           56000
# France              55000
# Canada              49000
# South Korea         41000

# %%
plt.figure(figsize=(12,7))
sns.barplot(data=top_10, x=top_10.index, y="Valuation")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Industry', data=comp)
plt.title('Bar Plot of Industry')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(x=comp['Valuation'],kde=True,bins=np.arange(0,175000,25000),color='g')
plt.title('Histogram of Valuation')
plt.xticks(rotation=30)
plt.show()

# %%
sns.histplot(comp["Return"],bins=20,color='m',kde=True)
plt.title('Distribution of Returns')
plt.show()

# %%
print(comp[(comp['Return'] == comp["Return"].min())].value_counts())
comp[(comp['Return'] == comp["Return"].max())].value_counts()
# Out:
# Company          Date Joined  Industry                         City     Country  Continent  Year Founded  Select Investors                                                   Funds  Valuation  Year Joined  Return  years_to_unicorn
# Miaoshou Doctor  6/27/2019    E-commerce & direct-to-consumer  Beijing  China    Asia       2015          Sequoia Capital China, Qiming Venture Partners, Tencent Holdings  90470   1000       2019         -89470  4                   1
# dtype: int64
# Company    Date Joined  Industry                 City     Country  Continent  Year Founded  Select Investors                                                          Funds  Valuation  Year Joined  Return  years_to_unicorn
# Bytedance  4/7/2017     Artificial Intelligence  Beijing  China    Asia       2012          Sequoia Capital China, SIG Asia Investments, Sina Weibo, Softbank Group  8000    180000     2017         172000  5                   1
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='Industry', y='Return', data=comp)
plt.title('Box Plot of Investors Count Grouped by Industry')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### Artificial Intelligence is the one of the industry which gives highest return.

# %%
sns.boxplot(x=comp['Year Joined'], 
            y=comp['years_to_unicorn'],  
            showfliers=False)

plt.title('Distribution of years to become unicorn with respect to Year joined')

# Rotate labels on the x-axis as a way to avoid overlap in the positions of the text. 

plt.xticks(rotation=45, horizontalalignment='right')
plt.show()

# %%
sns.lmplot(x="Return", y="Valuation", data=comp)
plt.title("Valuation vs. Return Amount")
plt.xlabel("Return Amount ($ Millions)")
plt.ylabel("Valuation ($ Millions)")
plt.show()

# %%
sns.lmplot(x="Valuation",y="Return",data=comp,hue='Industry')
plt.title('Valuation vs Return wrt Industry')
plt.show()

# %% [markdown]
# ##### Inference:
# 1. The top 3 industries which are producing the most unicorns, offering insights into emerging trends and investment opportunities are:- i)Fintech     ii)Internet software & services   iii)E-commerce & direct-to-consumer
# 2. The bottom 3 industries which are producing the least unicorns, offering less insights into emerging trends and investment opportunities are:- i)Travel     ii) Consumer & retail      iii)Edtech .

# %%
comp_grouped = (
    comp.groupby(["Year Founded", "Country","Company"])["Valuation"].sum().reset_index())

sns.lineplot(x="Year Founded", y="Valuation", data=comp_grouped)
plt.title("Unicorn Valuation Over Time by Country")
plt.show()

# %%
print(comp_grouped.max())
comp_grouped.min()
# Out:
# Year Founded       2021
# Country         Vietnam
# Company           wefox
# Valuation        180000
# dtype: object
# Year Founded          1919
# Country          Argentina
# Company         1047 Games
# Valuation             1000
# dtype: object

# %% [markdown]
# ##### Inference:
# Tracked the growth of unicorn valuations over time and compare trends across different countries or regions.
# 1. Highest valuation ie(180000) by wefox company in Vietnam country in year 2021.
# 2. Lowest valuation ie(1000) by 1047 Games in Argentina country in year 1919.

# %%
sns.jointplot(x='Valuation',y='years_to_unicorn',data=comp,kind='scatter',color='purple') 
plt.title('Valuation vs years_to_Unicorn',loc='right')
plt.show()

# %%
# Prepare data (assuming separate datasets for unicorns and non-unicorns
# Create scatter plot
plt.figure(figsize=(12,6))
sns.scatterplot(
    x=comp["Year Founded"],
    y=comp["years_to_unicorn"],
    label="Unicorns",
    alpha=0.7
)
plt.title("Time to Unicorn Status by Founding Year and Industry")
plt.xlabel("Founding Year")
plt.ylabel("Years to Unicorn")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Inference: Identified industries where unicorns tend to emerge faster and compare growth trajectories of successful vs. unsuccessful startups.

# %%
sns.barplot(x="Industry", y="Valuation", data=comp)
plt.title("Top 10 Industries by Average Valuation")
plt.xlabel("Industry")
plt.ylabel("Average Valuation ($Billions)")
plt.xticks(rotation=90)
plt.show()

# %%
comp[(comp["Valuation"] == comp["Valuation"].max())].value_counts()
# Out:
# Company    Date Joined  Industry                 City     Country  Continent  Year Founded  Select Investors                                                          Funds  Valuation  Year Joined  Return  years_to_unicorn
# Bytedance  4/7/2017     Artificial Intelligence  Beijing  China    Asia       2012          Sequoia Capital China, SIG Asia Investments, Sina Weibo, Softbank Group  8000    180000     2017         172000  5                   1
# dtype: int64

# %%
comp[(comp["Return"] == comp["Return"].min())].value_counts()
# Out:
# Company          Date Joined  Industry                         City     Country  Continent  Year Founded  Select Investors                                                   Funds  Valuation  Year Joined  Return  years_to_unicorn
# Miaoshou Doctor  6/27/2019    E-commerce & direct-to-consumer  Beijing  China    Asia       2015          Sequoia Capital China, Qiming Venture Partners, Tencent Holdings  90470   1000       2019         -89470  4                   1
# dtype: int64

# %%
sns.jointplot(y='years_to_unicorn',x='Return',data=comp,kind='reg',color='maroon') 
plt.title('Return vs Years_to_Unicorn',loc='right')
plt.show()

# %%
sns.pairplot(data=comp,hue="Continent",kind='scatter',palette='Set2')
plt.show()

# %%
comp.corr()
# Out:
#                   Year Founded     Funds  Valuation  Year Joined    Return  \
# Year Founded          1.000000 -0.011973  -0.074395     0.353961 -0.067939
#  Funds               -0.011973  1.000000   0.131224    -0.071173 -0.256244
# Valuation            -0.074395  0.131224   1.000000    -0.219981  0.924628
# Year Joined           0.353961 -0.071173  -0.219981     1.000000 -0.187146
# Return               -0.067939 -0.256244   0.924628    -0.187146  1.000000
# years_to_unicorn     -0.936304 -0.013923  -0.003058    -0.002962  0.002368
#
#                   years_to_unicorn
# Year Founded             -0.936304
#  Funds                   -0.013923
# Valuation                -0.003058
# Year Joined              -0.002962
# Return                    0.002368
# years_to_unicorn          1.000000

# %%
sns.heatmap(comp.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ##### Inference:
# 1. There are positive co-rrelations between :Valuation & Return,Year joined & Founded,Valuation and Funding.
# 2. There are negative co-rrelations between :year founded & to_unicorn,Funding & return,Valuation & year_joined.

# %% [markdown]
# ### Feature selection

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
comp.columns
# Out:
# Index(['Company', 'Date Joined', 'Industry', 'City', 'Country', 'Continent',
#        'Year Founded', 'Select Investors', ' Funds', 'Valuation',
#        'Year Joined', 'Return', 'years_to_unicorn'],
#       dtype='object')

# %%
comp['Industry']=le.fit_transform(comp['Industry'])
comp['City']=le.fit_transform(comp['City'])
comp['Company']=le.fit_transform(comp['Company'])

# %%
comp['Country']=le.fit_transform(comp['Country'])
comp['Continent']=le.fit_transform(comp['Continent'])
comp['Select Investors']=le.fit_transform(comp['Select Investors'])

# %%
comp
# Out:
#       Company Date Joined  Industry  City  Country  Continent  Year Founded  \
# 0         132    4/7/2017         0    14        9          1          2012
# 1         847   12/1/2012        12    97       44          3          2002
# 2         784    7/3/2018         5   218        9          1          2008
# 3         866   1/23/2014         7   202       44          3          2010
# 4         500  12/12/2011         7   225       38          2          2005
# ...       ...         ...       ...   ...      ...        ...           ...
# 1069     1040   6/29/2017         5   217        9          1          2012
# 1070     1041   4/18/2017         5    14        9          1          2015
# 1071     1043    5/6/2021         2    54        9          1          2018
# 1072     1049  10/19/2021         7   132       43          2          2005
# 1073     1052   9/16/2020         5   133       44          3          2014
#
# ...

# %%
x=comp[['Industry','City','Country','Continent',' Funds','Year Joined','Year Founded',
        'Return','years_to_unicorn','Company','Select Investors']].values    #'Company''Select Investors',
y=comp['Valuation'].values

# %%
x
# Out:
# array([[   0,   14,    9, ...,    5,  132,  804],
#        [  12,   97,   44, ...,   10,  847,  334],
#        [   5,  218,    9, ...,   10,  784,  961],
#        ...,
#        [   2,   54,    9, ...,    3, 1043, 1032],
#        [   7,  132,   43, ...,   16, 1049,  438],
#        [   5,  133,   44, ...,    6, 1052,  690]], dtype=int64)

# %%
y
# Out:
# array([180000, 100000, 100000, ...,   1000,   1000,   1000], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.30)

# %%
x_train
# Out:
# array([[  7, 204,  44, ...,  10, 901,   0],
#        [  7, 157,  19, ...,  22, 620, 901],
#        [  7, 202,  44, ...,   9, 908, 689],
#        ...,
#        [  5,  14,   9, ...,  15, 529, 934],
#        [  7, 132,  43, ...,   7, 895, 195],
#        [ 10,  18,  19, ...,  14,  41, 627]], dtype=int64)

# %%
x_train.shape
# Out:
# (751, 11)

# %%
y_train
# Out:
# array([  8000,   7000,   2000,   8000,   2000,   1000,   1000,   1000,
#          2000,   2000,   2000,  40000,   3000,   2000,   6000,   7000,
#          1000,   2000,   3000,   1000,   2000,   1000,   3000,   2000,
#          3000,   2000,   2000,   2000,   2000,   1000,   2000,   6000,
#          1000,   3000,   2000,   3000,   2000,  38000,   1000,   4000,
#          1000,   8000,   1000,   2000,   1000,   4000,   2000,   4000,
#          1000,   2000,   1000,   4000,   1000,   2000,   2000,   1000,
#          4000,   1000,   2000,   1000,   2000,   1000,   1000,   2000,
#         39000,   1000,   5000,   2000,   1000,   4000,   3000,   1000,
#          1000,   1000,   1000,   1000,   1000,   2000,   1000,   1000,
#          1000,   2000,   2000,   1000,   1000,   1000,   1000,   5000,
#          4000,   1000,   1000,   4000,   1000,   8000,   5000,   3000,
#          2000,   1000,   1000,   2000,  11000,   2000,   5000,   1000,
# ...

# %%
x_test.shape
# Out:
# (323, 11)

# %%
x_test
# Out:
# array([[ 10, 100,  15, ...,   5,  29, 502],
#        [  4,  14,   9, ...,   8, 486, 190],
#        [  9, 202,  44, ...,   7, 460, 598],
#        ...,
#        [ 12, 102,  22, ...,  10, 864, 781],
#        [ 10,  90,   9, ...,   5, 977, 266],
#        [ 11,  14,   9, ...,   4, 357, 842]], dtype=int64)

# %%
y_test
# Out:
# array([  2000,   2000,   3000,   2000,   3000,   4000,   2000,   2000,
#          2000,   1000,   2000,   1000,   5000,   3000,   2000,   2000,
#          1000,   2000,   1000,   1000,   3000,   1000,   1000,   4000,
#          1000,   2000,   1000,   4000,   1000,   1000,   4000,   3000,
#          6000,   1000,   1000,   3000,   2000,   7000,  10000,   1000,
#          2000,   3000,   1000,   3000,  12000,   2000,   1000,   1000,
#          2000,   3000,   2000,   2000,   1000,   1000,   2000,   2000,
#          1000,   5000,   1000,   3000,   1000,   2000,   2000,   1000,
#          1000,   6000,   6000,   9000,   1000,   3000,   2000,   2000,
#          1000,   2000,   1000,   1000,   7000,   1000,  10000,   1000,
#          1000,   1000,   2000,   2000,  15000,   3000,   1000,   2000,
#          2000,   1000,   1000,   3000,   3000,   5000,   1000,   1000,
#          1000,   1000,   7000,   2000,   1000,   1000,  10000,   1000,
# ...

# %% [markdown]
# ### Prediction using :
# #### 1. Linear Regression Algorithm:-

# %%
from sklearn.linear_model import LinearRegression

# %%
Lr=LinearRegression()
Lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_lr=Lr.predict(x_test)
y_pred_lr
# Out:
# array([  2000.,   2000.,   3000.,   2000.,   3000.,   4000.,   2000.,
#          2000.,   2000.,   1000.,   2000.,   1000.,   5000.,   3000.,
#          2000.,   2000.,   1000.,   2000.,   1000.,   1000.,   3000.,
#          1000.,   1000.,   4000.,   1000.,   2000.,   1000.,   4000.,
#          1000.,   1000.,   4000.,   3000.,   6000.,   1000.,   1000.,
#          3000.,   2000.,   7000.,  10000.,   1000.,   2000.,   3000.,
#          1000.,   3000.,  12000.,   2000.,   1000.,   1000.,   2000.,
#          3000.,   2000.,   2000.,   1000.,   1000.,   2000.,   2000.,
#          1000.,   5000.,   1000.,   3000.,   1000.,   2000.,   2000.,
#          1000.,   1000.,   6000.,   6000.,   9000.,   1000.,   3000.,
#          2000.,   2000.,   1000.,   2000.,   1000.,   1000.,   7000.,
#          1000.,  10000.,   1000.,   1000.,   1000.,   2000.,   2000.,
#         15000.,   3000.,   1000.,   2000.,   2000.,   1000.,   1000.,
# ...

# %%
y_test
# Out:
# array([  2000,   2000,   3000,   2000,   3000,   4000,   2000,   2000,
#          2000,   1000,   2000,   1000,   5000,   3000,   2000,   2000,
#          1000,   2000,   1000,   1000,   3000,   1000,   1000,   4000,
#          1000,   2000,   1000,   4000,   1000,   1000,   4000,   3000,
#          6000,   1000,   1000,   3000,   2000,   7000,  10000,   1000,
#          2000,   3000,   1000,   3000,  12000,   2000,   1000,   1000,
#          2000,   3000,   2000,   2000,   1000,   1000,   2000,   2000,
#          1000,   5000,   1000,   3000,   1000,   2000,   2000,   1000,
#          1000,   6000,   6000,   9000,   1000,   3000,   2000,   2000,
#          1000,   2000,   1000,   1000,   7000,   1000,  10000,   1000,
#          1000,   1000,   2000,   2000,  15000,   3000,   1000,   2000,
#          2000,   1000,   1000,   3000,   3000,   5000,   1000,   1000,
#          1000,   1000,   7000,   2000,   1000,   1000,  10000,   1000,
# ...

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
lracc=r2_score(y_test,y_pred_lr)
lracc
# Out:
# 1.0

# %%
mae_lr=mean_absolute_error(y_test,y_pred_lr)
mse_lr=mean_squared_error(y_test,y_pred_lr)
rmse_lr=np.sqrt(mse_lr)

# %%
print(mae_lr,mse_lr,rmse_lr)
# Out:
# 2.2124936901488493e-12 9.556593040577327e-24 3.091373972941049e-12

# %% [markdown]
# #### 2. KNN Algorithm:-

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
Knn=KNeighborsRegressor(n_neighbors=7)
Knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=7)

# %%
y_pred_knn=Knn.predict(x_test)
y_pred_knn
# Out:
# array([ 2000.        ,  2000.        ,  3000.        ,  2000.        ,
#         3000.        ,  4000.        ,  2000.        ,  2000.        ,
#         2000.        ,  1000.        ,  2000.        ,  1000.        ,
#         5000.        ,  3000.        ,  2000.        ,  2000.        ,
#         1000.        ,  2000.        ,  1000.        ,  1000.        ,
#         3000.        ,  1000.        ,  1000.        ,  4000.        ,
#         1142.85714286,  2000.        ,  1000.        ,  4000.        ,
#         1000.        ,  1000.        ,  4000.        ,  3000.        ,
#         6000.        ,  1000.        ,  1000.        ,  3000.        ,
#         2000.        ,  7000.        , 10142.85714286,  1000.        ,
#         2000.        ,  3000.        ,  1000.        ,  3000.        ,
#        11857.14285714,  2000.        ,  1000.        ,  1000.        ,
#         2000.        ,  3000.        ,  2000.        ,  2000.        ,
# ...

# %%
y_test
# Out:
# array([  2000,   2000,   3000,   2000,   3000,   4000,   2000,   2000,
#          2000,   1000,   2000,   1000,   5000,   3000,   2000,   2000,
#          1000,   2000,   1000,   1000,   3000,   1000,   1000,   4000,
#          1000,   2000,   1000,   4000,   1000,   1000,   4000,   3000,
#          6000,   1000,   1000,   3000,   2000,   7000,  10000,   1000,
#          2000,   3000,   1000,   3000,  12000,   2000,   1000,   1000,
#          2000,   3000,   2000,   2000,   1000,   1000,   2000,   2000,
#          1000,   5000,   1000,   3000,   1000,   2000,   2000,   1000,
#          1000,   6000,   6000,   9000,   1000,   3000,   2000,   2000,
#          1000,   2000,   1000,   1000,   7000,   1000,  10000,   1000,
#          1000,   1000,   2000,   2000,  15000,   3000,   1000,   2000,
#          2000,   1000,   1000,   3000,   3000,   5000,   1000,   1000,
#          1000,   1000,   7000,   2000,   1000,   1000,  10000,   1000,
# ...

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
knnacc=r2_score(y_test,y_pred_knn)
knnacc
# Out:
# 0.7709857173774435

# %%
mae_knn=mean_absolute_error(y_test,y_pred_knn)
mse_knn=mean_squared_error(y_test,y_pred_knn)
rmse_knn=np.sqrt(mse_knn)
print(mae_knn,mse_knn,rmse_knn)
# Out:
# 367.97877045555066 15370695.646679722 3920.5478758305862

# %% [markdown]
# #### 3. Decision Tree:-

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor

# %%
Dtr=DecisionTreeRegressor(max_depth=3)
Dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
from sklearn import tree
plt.figure(figsize=(12,6))
tree.plot_tree(Dtr,filled=True)
plt.show()

# %%
y_pred_dtr=Dtr.predict(x_test)
y_pred_dtr
# Out:
# array([  1920.65868263,   1920.65868263,   1920.65868263,   1920.65868263,
#          1920.65868263,   1920.65868263,   1920.65868263,   1920.65868263,
#          1920.65868263,   1920.65868263,   1920.65868263,   1920.65868263,
#          1920.65868263,   1920.65868263,   1920.65868263,   1920.65868263,
#          1920.65868263,   1920.65868263,   1920.65868263,   1920.65868263,
#          1920.65868263,   1920.65868263,   1920.65868263,   1920.65868263,
#          1920.65868263,   1920.65868263,   1920.65868263,   1920.65868263,
#          1920.65868263,   1920.65868263,   1920.65868263,   1920.65868263,
#          8955.88235294,   1920.65868263,   1920.65868263,   1920.65868263,
#          1920.65868263,   8955.88235294,   8955.88235294,   1920.65868263,
#          1920.65868263,   1920.65868263,   1920.65868263,   1920.65868263,
#          8955.88235294,   1920.65868263,   1920.65868263,   1920.65868263,
# ...

# %%
y_test
# Out:
# array([  2000,   2000,   3000,   2000,   3000,   4000,   2000,   2000,
#          2000,   1000,   2000,   1000,   5000,   3000,   2000,   2000,
#          1000,   2000,   1000,   1000,   3000,   1000,   1000,   4000,
#          1000,   2000,   1000,   4000,   1000,   1000,   4000,   3000,
#          6000,   1000,   1000,   3000,   2000,   7000,  10000,   1000,
#          2000,   3000,   1000,   3000,  12000,   2000,   1000,   1000,
#          2000,   3000,   2000,   2000,   1000,   1000,   2000,   2000,
#          1000,   5000,   1000,   3000,   1000,   2000,   2000,   1000,
#          1000,   6000,   6000,   9000,   1000,   3000,   2000,   2000,
#          1000,   2000,   1000,   1000,   7000,   1000,  10000,   1000,
#          1000,   1000,   2000,   2000,  15000,   3000,   1000,   2000,
#          2000,   1000,   1000,   3000,   3000,   5000,   1000,   1000,
#          1000,   1000,   7000,   2000,   1000,   1000,  10000,   1000,
# ...

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
dtracc=r2_score(y_test,y_pred_dtr)  
dtracc
# Out:
# 0.9721678955034587

# %%
mae_dtr=mean_absolute_error(y_test,y_pred_dtr)
mse_dtr=mean_squared_error(y_test,y_pred_dtr)
rmse_dtr=np.sqrt(mse_dtr)
print(mae_dtr,mse_dtr,rmse_dtr)
# Out:
# 996.634939918015 1868000.5566639155 1366.7481687069917

# %% [markdown]
# #### 4. Random Forest:-

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RF=RandomForestRegressor(random_state=42,n_jobs=-1,max_depth=5,n_estimators=100)
RF.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=5, n_jobs=-1, random_state=42)

# %%
y_pred_rfr=RF.predict(x_test)
y_pred_rfr
# Out:
# array([ 2012.15286675,  2012.15286675,  3032.81158496,  2012.15286675,
#         3032.81158496,  4201.84829876,  2012.15286675,  2012.15286675,
#         2012.15286675,  1002.07222672,  2012.15286675,  1002.07222672,
#         4930.34495544,  3032.81158496,  2012.15286675,  2012.15286675,
#         1002.07222672,  2345.99243216,  1002.07222672,  1002.07222672,
#         3032.81158496,  1002.07222672,  1002.07222672,  4172.04437719,
#         1021.40556005,  2012.15286675,  1002.07222672,  4172.04437719,
#         1002.07222672,  1002.07222672,  4172.04437719,  3032.81158496,
#         6047.02638752,  1002.07222672,  1002.07222672,  3032.81158496,
#         2012.15286675,  7839.64178122,  8999.97183894,  1002.07222672,
#         2012.15286675,  3032.81158496,  1002.07222672,  3032.81158496,
#        12287.80898165,  2012.15286675,  1002.07222672,  1002.07222672,
#         2012.15286675,  3032.81158496,  2012.15286675,  2012.15286675,
# ...

# %%
y_test
# Out:
# array([  2000,   2000,   3000,   2000,   3000,   4000,   2000,   2000,
#          2000,   1000,   2000,   1000,   5000,   3000,   2000,   2000,
#          1000,   2000,   1000,   1000,   3000,   1000,   1000,   4000,
#          1000,   2000,   1000,   4000,   1000,   1000,   4000,   3000,
#          6000,   1000,   1000,   3000,   2000,   7000,  10000,   1000,
#          2000,   3000,   1000,   3000,  12000,   2000,   1000,   1000,
#          2000,   3000,   2000,   2000,   1000,   1000,   2000,   2000,
#          1000,   5000,   1000,   3000,   1000,   2000,   2000,   1000,
#          1000,   6000,   6000,   9000,   1000,   3000,   2000,   2000,
#          1000,   2000,   1000,   1000,   7000,   1000,  10000,   1000,
#          1000,   1000,   2000,   2000,  15000,   3000,   1000,   2000,
#          2000,   1000,   1000,   3000,   3000,   5000,   1000,   1000,
#          1000,   1000,   7000,   2000,   1000,   1000,  10000,   1000,
# ...

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
rfracc=r2_score(y_test,y_pred_rfr)
rfracc
# Out:
# 0.9673163063109217

# %%
mae_rfr=mean_absolute_error(y_test,y_pred_rfr)
mse_rfr=mean_squared_error(y_test,y_pred_rfr)
rmse_rfr=np.sqrt(mse_rfr)
print(mae_rfr,mse_rfr,rmse_rfr)
# Out:
# 253.66198196887322 2193623.483003885 1481.0886141632056

# %% [markdown]
# #### 5. Gradient Boosting :-

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
Gbr = GradientBoostingRegressor(random_state=42)
Gbr.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
y_pred_gbr= Gbr.predict(x_test)
y_pred_gbr
# Out:
# array([  2000.74273538,   2000.74273538,   2994.37132135,   2000.74273538,
#          2999.63904464,   4011.55482228,   2000.74273538,   2000.74273538,
#          2000.74273538,   1003.65892159,   2000.74273538,   1003.65892159,
#          4979.29383522,   2994.37132135,   2000.74273538,   2000.74273538,
#          1003.65892159,   2000.74273538,   1003.65892159,   1003.65892159,
#          2990.85351387,   1003.65892159,   1003.65892159,   4011.55482228,
#          1328.80257686,   2000.74273538,   1003.65892159,   4011.55482228,
#          1003.65892159,   1003.65892159,   4011.55482228,   2994.37132135,
#          5940.02476497,   1003.65892159,   1003.65892159,   2999.63904464,
#          2000.74273538,   7144.69573972,   9926.89147981,   1003.65892159,
#          2000.74273538,   2994.37132135,   1003.65892159,   2994.37132135,
#         12091.01040058,   2000.74273538,   1003.65892159,   1003.65892159,
# ...

# %%
new_data = [[5,133,44,3,620,2020,2014,380,6,1052,690]]  # Replace with your new data point
new_prediction = Gbr.predict(new_data)
print("Predicted value:", new_prediction)
# Out:
# Predicted value: [1003.65892159]

# %%
y_test
# Out:
# array([  2000,   2000,   3000,   2000,   3000,   4000,   2000,   2000,
#          2000,   1000,   2000,   1000,   5000,   3000,   2000,   2000,
#          1000,   2000,   1000,   1000,   3000,   1000,   1000,   4000,
#          1000,   2000,   1000,   4000,   1000,   1000,   4000,   3000,
#          6000,   1000,   1000,   3000,   2000,   7000,  10000,   1000,
#          2000,   3000,   1000,   3000,  12000,   2000,   1000,   1000,
#          2000,   3000,   2000,   2000,   1000,   1000,   2000,   2000,
#          1000,   5000,   1000,   3000,   1000,   2000,   2000,   1000,
#          1000,   6000,   6000,   9000,   1000,   3000,   2000,   2000,
#          1000,   2000,   1000,   1000,   7000,   1000,  10000,   1000,
#          1000,   1000,   2000,   2000,  15000,   3000,   1000,   2000,
#          2000,   1000,   1000,   3000,   3000,   5000,   1000,   1000,
#          1000,   1000,   7000,   2000,   1000,   1000,  10000,   1000,
# ...

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
gbracc=r2_score(y_test,y_pred_gbr)
gbracc
# Out:
# 0.945975639037226

# %%
mae_gbr=mean_absolute_error(y_test,y_pred_gbr)
mse_gbr=mean_squared_error(y_test,y_pred_gbr)
rmse_gbr=np.sqrt(mse_gbr)
print(mae_gbr,mse_gbr,rmse_gbr)
# Out:
# 174.9964434333896 3625939.8337777504 1904.1900729123

# %%
result=[]
mae=[]
mse=[]
rmse=[]
result.extend([lracc,knnacc,dtracc,rfracc,gbracc])
mae.extend([mae_lr,mae_knn,mae_dtr,mae_rfr,mae_gbr])
mse.extend([mse_lr,mse_knn,mse_dtr,mse_rfr,mse_gbr])
rmse.extend([rmse_lr,rmse_knn,rmse_dtr,rmse_rfr,rmse_gbr])
Algorithms=["Linear Regression","K Nearest Neighbour","Decision Tree","Random Forest","Gradient Boosting"]

# %%
print(result,mae,mse,rmse)
# Out:
# [1.0, 0.7709857173774435, 0.9721678955034587, 0.9673163063109217, 0.945975639037226] [2.2124936901488493e-12, 367.97877045555066, 996.634939918015, 253.66198196887322, 174.9964434333896] [9.556593040577327e-24, 15370695.646679722, 1868000.5566639155, 2193623.483003885, 3625939.8337777504] [3.091373972941049e-12, 3920.5478758305862, 1366.7481687069917, 1481.0886141632056, 1904.1900729123]

# %%
df=DataFrame({"Accuracy":result,"MAE":mae,"MSE":mse,"RMSE":rmse},index=Algorithms)

# %%
df
# Out:
#                    Accuracy           MAE           MSE          RMSE
# Linear Regression  1.000000  2.212494e-12  9.556593e-24  3.091374e-12
# KNN                0.770986  3.679788e+02  1.537070e+07  3.920548e+03
# Decision Tree      0.972168  9.966349e+02  1.868001e+06  1.366748e+03
# Random Forest      0.967316  2.536620e+02  2.193623e+06  1.481089e+03
# Gradient Boosting  0.945976  1.749964e+02  3.625940e+06  1.904190e+03

# %% [markdown]
# #### Conclusion:
# Here, Linear regression algorithm is best fit for model.
# 1. There are 1074 unicorn companies represented in this dataset.
# 2. 2015 is the year when the most number of unicorn companies were founded.
# 3. Many of the unicorn companies that were founded in 2021 were founded in the United States and belong to "Fintech", "E-commerce & direct-to-consumer", and "Internet software & services" industries.
# 4. One of the bar plots created shows that the average valuation of companies that joined in 2020 is highestas well as  the average valuation of companies that joined in 2021.
